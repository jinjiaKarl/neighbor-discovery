# %%
print(df_25_30)
# Out:
#      Total Time Signature Verification Time  HMAC Comparison Time  \
# 0      0.873173      [0.001851797103881836]              0.000558
# 1      0.759539      [0.002112865447998047]              0.000450
# 2      0.624943      [0.001829385757446289]              0.000955
# 3      0.713830     [0.0032122135162353516]              0.000481
# 4      0.478138     [0.0018610954284667969]              0.000357
# ..          ...                         ...                   ...
# 995    1.861803     [0.0018131732940673828]              0.000384
# 996    1.053408     [0.0017294883728027344]              0.000331
# 997    1.026625     [0.0016324520111083984]              0.000329
# 998    1.183084      [0.002081632614135742]              0.000371
# 999    1.163837     [0.0016770362854003906]              0.000376
#
#                 Signing Time   AES-GCM Encryption Time
# 0     [0.001714944839477539]  [0.00027751922607421875]
# 1     [0.001138925552368164]  [0.00017380714416503906]
# 2     [0.001775503158569336]   [0.0004100799560546875]
# 3    [0.0013282299041748047]   [0.0003070831298828125]
# 4    [0.0011951923370361328]  [0.00026154518127441406]
# ..                       ...                       ...
# 995    [0.01309967041015625]   [0.0019812583923339844]
# 996   [0.008200407028198242]      [0.0008087158203125]
# 997    [0.01552438735961914]   [0.0017631053924560547]
# 998    [0.01129460334777832]   [0.0009653568267822266]
# 999   [0.015523910522460938]   [0.0007722377777099609]
#
# [1000 rows x 5 columns]

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.patches import Patch

df_25_15 = pd.read_csv('./data/timelocation/receiver_time_location_0_25_15_protocol.csv')
df_25_30 = pd.read_csv('./data/timelocation/receiver_time_location_0_25_30_protocol.csv')
df_50_15 = pd.read_csv('./data/timelocation/receiver_time_location_25_50_15_protocol.csv')
df_50_30 = pd.read_csv('./data/timelocation/receiver_time_location_25_50_30_protocol.csv')
df_75_15 = pd.read_csv('./data/timelocation/receiver_time_location_50_75_15_protocol.csv')
df_75_30 = pd.read_csv('./data/timelocation/receiver_time_location_50_75_30_protocol.csv')


# Choose a column to compare
column_to_compare = 'Total Time'
scientific_colors = ['#1f77b4', '#ff7f0e', '#2ca02c', '#d62728', '#9467bd', '#8c564b', '#e377c2', '#7f7f7f', '#bcbd22']
# Extract data for the chosen column from the concatenated DataFrames
data_columns_concatenated = {
    '25_15': df_25_15[column_to_compare],
     '25_30': df_25_30[column_to_compare],
     '50_15': df_50_15[column_to_compare],
     '50_30': df_50_30[column_to_compare],
     '75_15': df_75_15[column_to_compare],
     '75_30': df_75_30[column_to_compare],
    
    }

# Calculate mean and standard deviation
means = [data_column.mean() for data_column in data_columns_concatenated.values()]
std_devs = [data_column.std() for data_column in data_columns_concatenated.values()]
n_values = [len(data_column) for data_column in data_columns_concatenated.values()]

# Calculate 95% confidence interval
ci = [1.96 * std_dev / np.sqrt(n) for std_dev, n in zip(std_devs, n_values)]

# Prepare data for plotting
keys = list(data_columns_concatenated.keys())
x_pos = np.arange(len(keys))

# Plot bar graph with mean and standard deviation
plt.figure(figsize=(10, 6))
bars = plt.bar(x_pos, means, yerr=ci, align='center', alpha=0.7, ecolor='black', capsize=10, width=0.5, color=scientific_colors, edgecolor='black')

# Customize legend
legend_elements = [Patch(facecolor=color, label=key) for key, color in zip(keys, scientific_colors)]
plt.legend(handles=legend_elements, loc='upper left', bbox_to_anchor=(1, 1), title='Keys', frameon=False)

# Remove x-axis labels
plt.xticks([])

# Add data labels on top of the bars
for i, mean in enumerate(means):
    plt.text(x_pos[i], mean + 0.02 * max(means), f'{mean:.3f}', ha='center', va='bottom', fontsize=9)

plt.xlabel('Keys', fontsize=12)
plt.ylabel('Time (s)', fontsize=12)
plt.title(f'Total time in time-location Protocol at 95% CI', fontsize=14)

# Remove the top and right spines for aesthetics
plt.gca().spines['top'].set_visible(False)
plt.gca().spines['right'].set_visible(False)

plt.show()

# %%
print(means)
print(ci)
# Out:
# [0.47617726348899997, 0.9768291537780001, 0.894993547199, 1.576954938177, 1.228557272438, 2.083077701316]
# [0.010702849964520728, 0.023356187917318222, 0.02535022892046689, 0.04158563627653643, 0.038424744389013, 0.05820132530917114]

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.patches import Patch

df_25_15 = pd.read_csv('./data/timelocation/receiver_time_location_0_25_15_protocol.csv')
df_25_30 = pd.read_csv('./data/timelocation/receiver_time_location_0_25_30_protocol.csv')
df_50_15 = pd.read_csv('./data/timelocation/receiver_time_location_25_50_15_protocol.csv')
df_50_30 = pd.read_csv('./data/timelocation/receiver_time_location_25_50_30_protocol.csv')
df_75_15 = pd.read_csv('./data/timelocation/receiver_time_location_50_75_15_protocol.csv')
df_75_30 = pd.read_csv('./data/timelocation/receiver_time_location_50_75_30_protocol.csv')


# Choose a column to compare
column_to_compare = 'HMAC Comparison Time'
scientific_colors = ['#1f77b4', '#ff7f0e', '#2ca02c', '#d62728', '#9467bd', '#8c564b', '#e377c2', '#7f7f7f', '#bcbd22']
# Extract data for the chosen column from the concatenated DataFrames
data_columns_concatenated = {
    '25_15': df_25_15[column_to_compare],
     '25_30': df_25_30[column_to_compare],
     '50_15': df_50_15[column_to_compare],
     '50_30': df_50_30[column_to_compare],
     '75_15': df_75_15[column_to_compare],
     '75_30': df_75_30[column_to_compare],
    
    }

# Calculate mean and standard deviation
means = [data_column.mean() for data_column in data_columns_concatenated.values()]
std_devs = [data_column.std() for data_column in data_columns_concatenated.values()]
n_values = [len(data_column) for data_column in data_columns_concatenated.values()]

# Calculate 95% confidence interval
ci = [1.96 * std_dev / np.sqrt(n) for std_dev, n in zip(std_devs, n_values)]

# Prepare data for plotting
keys = list(data_columns_concatenated.keys())
x_pos = np.arange(len(keys))

# Plot bar graph with mean and standard deviation
plt.figure(figsize=(10, 6))
bars = plt.bar(x_pos, means, yerr=ci, align='center', alpha=0.7, ecolor='black', capsize=10, width=0.5, color=scientific_colors, edgecolor='black')

# Customize legend
legend_elements = [Patch(facecolor=color, label=key) for key, color in zip(keys, scientific_colors)]
plt.legend(handles=legend_elements, loc='upper left', bbox_to_anchor=(1, 1), title='Keys', frameon=False)

# Remove x-axis labels
plt.xticks([])

# Add data labels on top of the bars
for i, mean in enumerate(means):
    plt.text(x_pos[i], mean + 0.02 * max(means), f'{mean:.3f}', ha='center', va='bottom', fontsize=9)

plt.xlabel('Keys', fontsize=12)
plt.ylabel('Time (s)', fontsize=12)
plt.title(f'HMAC Comparison time in time-location Protocol at 95% CI', fontsize=14)

# Remove the top and right spines for aesthetics
plt.gca().spines['top'].set_visible(False)
plt.gca().spines['right'].set_visible(False)

plt.show()

# %%
print(means)
print(ci)
# Out:
# [0.000645174959, 0.000575619448, 0.0006641137639999999, 0.0005888085190000001, 0.000492636428, 0.000566910514]
# [4.430312122813697e-05, 4.119097449444999e-05, 6.659064133870705e-05, 3.393421695886889e-05, 4.030791260036383e-05, 3.891464676904837e-05]

# %%
# Choose a column to compare

# Extract data for the chosen column from the concatenated DataFrames
data_columns_concatenated = {
    '25_15_sign': df_25_15['Signing Time'].apply(lambda x: eval(x)[0]),
    '25_15_verify': df_25_15['Signature Verification Time'].apply(lambda x: eval(x)[0]),
     '25_30_sign': df_25_30['Signing Time'].apply(lambda x: eval(x)[0]),
    '25_30_verify': df_25_30['Signature Verification Time'].apply(lambda x: eval(x)[0]),
     '50_15_sign': df_50_15['Signing Time'].apply(lambda x: eval(x)[0]),
    '50_15_verify': df_50_15['Signature Verification Time'].apply(lambda x: eval(x)[0]),
     '50_30_sign': df_50_30['Signing Time'].apply(lambda x: eval(x)[0]),
    '50_30_verify': df_50_30['Signature Verification Time'].apply(lambda x: eval(x)[0]),
    '75_15_sign': df_75_15['Signing Time'].apply(lambda x: eval(x)[0]),
    '75_15_verify': df_75_15['Signature Verification Time'].apply(lambda x: eval(x)[0]),
     '75_30_sign': df_75_30['Signing Time'].apply(lambda x: eval(x)[0]),
    '75_30_verify': df_75_30['Signature Verification Time'].apply(lambda x: eval(x)[0]),
    
     }


# Calculate mean and standard deviation
means = [data_column.mean() for data_column in data_columns_concatenated.values()]
std_devs = [data_column.std() for data_column in data_columns_concatenated.values()]

n_values = [len(data_column) for data_column in data_columns_concatenated.values()]

# Calculate 95% confidence interval
ci = [1.96 * std_dev / np.sqrt(n) for std_dev, n in zip(std_devs, n_values)]

# Prepare data for plotting
keys = list(data_columns_concatenated.keys())
x_pos = np.arange(len(keys))

# Plot bar graph with mean and standard deviation
plt.figure(figsize=(10, 6))
bars = plt.bar(x_pos, means, yerr=ci, align='center', alpha=0.7, ecolor='black', capsize=10, width=0.5, color=scientific_colors, edgecolor='black')

# Customize legend
legend_elements = [Patch(facecolor=color, label=key) for key, color in zip(keys, scientific_colors)]
plt.legend(handles=legend_elements, loc='upper left', bbox_to_anchor=(1, 1), title='Keys', frameon=False)

# Remove x-axis labels
plt.xticks([])

# Add data labels on top of the bars
for i, mean in enumerate(means):
    plt.text(x_pos[i], mean + 0.02 * max(means), f'{mean:.4f}', ha='center', va='bottom', fontsize=9)

plt.xlabel('Keys', fontsize=12)
plt.ylabel('Time (s)', fontsize=12)
plt.title(f'Signing and Verification Time for Fully-secure at 95% CI', fontsize=14)

# Remove the top and right spines for aesthetics
plt.gca().spines['top'].set_visible(False)
plt.gca().spines['right'].set_visible(False)

plt.show()

# %%
print(means)
print(ci)
# Out:
# [0.008551562309265136, 0.003225331544876099, 0.0074395668506622315, 0.0025639715194702146, 0.009134926557540893, 0.0031593427658081056, 0.008509754180908203, 0.0027971537113189696, 0.006978864192962646, 0.0021205289363861084, 0.007708348035812378, 0.0027516703605651857]
# [0.0005802025375529859, 0.00019825641736781978, 0.00048168504594234675, 0.00013155224327032994, 0.0006517626116779833, 0.00020489944356794388, 0.0005525713257217756, 0.00012454622163655387, 0.000458461660314568, 6.076145897399833e-05, 0.0005203500978332714, 0.00013510193892981993]

# %%
# Choose a column to compare

# Extract data for the chosen column from the concatenated DataFrames
data_columns_concatenated = {
    '25_15_sign': df_25_15['AES-GCM Encryption Time'].apply(lambda x: eval(x)[0]),
    '25_30_sign': df_25_30['AES-GCM Encryption Time'].apply(lambda x: eval(x)[0]),
    '50_15_sign': df_50_15['AES-GCM Encryption Time'].apply(lambda x: eval(x)[0]),
     '50_30_sign': df_50_30['AES-GCM Encryption Time'].apply(lambda x: eval(x)[0]),
    '75_15_sign': df_75_15['AES-GCM Encryption Time'].apply(lambda x: eval(x)[0]),
     '75_30_sign': df_75_30['AES-GCM Encryption Time'].apply(lambda x: eval(x)[0]),
    
     }


# Calculate mean and standard deviation
means = [data_column.mean() for data_column in data_columns_concatenated.values()]
std_devs = [data_column.std() for data_column in data_columns_concatenated.values()]

n_values = [len(data_column) for data_column in data_columns_concatenated.values()]

# Calculate 95% confidence interval
ci = [1.96 * std_dev / np.sqrt(n) for std_dev, n in zip(std_devs, n_values)]

# Prepare data for plotting
keys = list(data_columns_concatenated.keys())
x_pos = np.arange(len(keys))

# Plot bar graph with mean and standard deviation
plt.figure(figsize=(10, 6))
bars = plt.bar(x_pos, means, yerr=ci, align='center', alpha=0.7, ecolor='black', capsize=10, width=0.5, color=scientific_colors, edgecolor='black')

# Customize legend
legend_elements = [Patch(facecolor=color, label=key) for key, color in zip(keys, scientific_colors)]
plt.legend(handles=legend_elements, loc='upper left', bbox_to_anchor=(1, 1), title='Keys', frameon=False)

# Remove x-axis labels
plt.xticks([])

# Add data labels on top of the bars
for i, mean in enumerate(means):
    plt.text(x_pos[i], mean + 0.02 * max(means), f'{mean:.4f}', ha='center', va='bottom', fontsize=9)

plt.xlabel('Keys', fontsize=12)
plt.ylabel('Time (s)', fontsize=12)
plt.title(f'AES-GCM Encryption Time for Fully-secure at 95% CI', fontsize=14)

# Remove the top and right spines for aesthetics
plt.gca().spines['top'].set_visible(False)
plt.gca().spines['right'].set_visible(False)

plt.show()

# %%
print(means)
print(ci)
# Out:
# [0.0007973482608795166, 0.0006659030914306641, 0.0008128354549407959, 0.000783167839050293, 0.0006284985542297363, 0.0007302477359771728]
# [5.3599933287003926e-05, 3.471765395075152e-05, 5.487333512303911e-05, 4.518213685221131e-05, 3.280417615270333e-05, 4.574099945903751e-05]
