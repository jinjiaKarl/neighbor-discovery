# %%
print(df_25_30)
# Out:
#      Total Time Signature Verification Time  HMAC Comparison Time  \
# 0      0.482624     [0.0012149810791015625]              0.000213
# 1      0.663601     [0.0012738704681396484]              0.000247
# 2      0.691110     [0.0014562606811523438]              0.000246
# 3      0.604411     [0.0012869834899902344]              0.000194
# 4      0.409623     [0.0012819766998291016]              0.000231
# ..          ...                         ...                   ...
# 995    0.965756     [0.0012559890747070312]              0.000187
# 996    1.302000     [0.0012371540069580078]              0.000179
# 997    1.241678     [0.0012500286102294922]              0.000317
# 998    0.968586     [0.0011610984802246094]              0.000222
# 999    0.806788     [0.0011670589447021484]              0.000183
#
#                 Signing Time   AES-GCM Encryption Time
# 0    [0.0008671283721923828]   [0.0011718273162841797]
# 1    [0.0008828639984130859]  [0.00033283233642578125]
# 2    [0.0008859634399414062]   [0.0004131793975830078]
# 3    [0.0008168220520019531]   [0.0004298686981201172]
# 4    [0.0008919239044189453]    [0.001165151596069336]
# ..                       ...                       ...
# 995   [0.011806964874267578]   [0.0003418922424316406]
# 996   [0.011451959609985352]  [0.00033783912658691406]
# 997   [0.010267972946166992]  [0.00045990943908691406]
# 998   [0.008217811584472656]  [0.00039577484130859375]
# 999   [0.008636951446533203]   [0.0003209114074707031]
#
# [1000 rows x 5 columns]

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.patches import Patch

df_25_15 = pd.read_csv('./data/fully-secure/receiver_fully_secure_protocol_noise_25_dis_15.csv')
df_25_30 = pd.read_csv('./data/fully-secure/receiver_fully_secure_protocol_noise_25_dis_30.csv')
df_50_15 = pd.read_csv('./data/fully-secure/receiver_fully_secure_protocol_noise_50_dis_15.csv')
df_50_30 = pd.read_csv('./data/fully-secure/receiver_fully_secure_protocol_noise_50_dis_30.csv')
df_75_15 = pd.read_csv('./data/fully-secure/receiver_fully_secure_protocol_noise_75_dis_15.csv')
df_75_30 = pd.read_csv('./data/fully-secure/receiver_fully_secure_protocol_noise_75_dis_30.csv')


# Choose a column to compare
column_to_compare = 'Total Time'
scientific_colors = ['#1f77b4', '#ff7f0e', '#2ca02c', '#d62728', '#9467bd', '#8c564b', '#e377c2', '#7f7f7f', '#bcbd22']
# Extract data for the chosen column from the concatenated DataFrames
data_columns_concatenated = {
    '25_15': df_25_15[column_to_compare],
     '25_30': df_25_30[column_to_compare],
     '50_15': df_50_15[column_to_compare],
     '50_30': df_50_30[column_to_compare],
     '75_15': df_75_15[column_to_compare],
     '75_30': df_75_30[column_to_compare],
    
    }

# Calculate mean and standard deviation
means = [data_column.mean() for data_column in data_columns_concatenated.values()]
std_devs = [data_column.std() for data_column in data_columns_concatenated.values()]
n_values = [len(data_column) for data_column in data_columns_concatenated.values()]

# Calculate 95% confidence interval
ci = [1.96 * std_dev / np.sqrt(n) for std_dev, n in zip(std_devs, n_values)]

# Prepare data for plotting
keys = list(data_columns_concatenated.keys())
x_pos = np.arange(len(keys))

# Plot bar graph with mean and standard deviation
plt.figure(figsize=(10, 6))
bars = plt.bar(x_pos, means, yerr=ci, align='center', alpha=0.7, ecolor='black', capsize=10, width=0.5, color=scientific_colors, edgecolor='black')

# Customize legend
legend_elements = [Patch(facecolor=color, label=key) for key, color in zip(keys, scientific_colors)]
plt.legend(handles=legend_elements, loc='upper left', bbox_to_anchor=(1, 1), title='Keys', frameon=False)

# Remove x-axis labels
plt.xticks([])

# Add data labels on top of the bars
for i, mean in enumerate(means):
    plt.text(x_pos[i], mean + 0.02 * max(means), f'{mean:.3f}', ha='center', va='bottom', fontsize=9)

plt.xlabel('Keys', fontsize=12)
plt.ylabel('Time (s)', fontsize=12)
plt.title(f'Total time in Fully-secure Protocol at 95% CI', fontsize=14)

# Remove the top and right spines for aesthetics
plt.gca().spines['top'].set_visible(False)
plt.gca().spines['right'].set_visible(False)

plt.show()

# %%
print(means)
print(ci)
# Out:
# [0.4643623730961923, 0.892800181877, 1.363369901888, 1.475816080813, 1.2832021655967907, 2.0995406453570005]
# [0.010726900991798408, 0.019598923211712353, 0.0397532772447556, 0.039758636844247616, 0.2809848289627865, 0.05796132478029528]

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.patches import Patch

df_25_15 = pd.read_csv('./data/fully-secure/receiver_fully_secure_protocol_noise_25_dis_15.csv')
df_25_30 = pd.read_csv('./data/fully-secure/receiver_fully_secure_protocol_noise_25_dis_30.csv')
df_50_15 = pd.read_csv('./data/fully-secure/receiver_fully_secure_protocol_noise_50_dis_15.csv')
df_50_30 = pd.read_csv('./data/fully-secure/receiver_fully_secure_protocol_noise_50_dis_30.csv')
df_75_15 = pd.read_csv('./data/fully-secure/receiver_fully_secure_protocol_noise_75_dis_15.csv')
df_75_30 = pd.read_csv('./data/fully-secure/receiver_fully_secure_protocol_noise_75_dis_30.csv')


# Choose a column to compare
column_to_compare = 'HMAC Comparison Time'
scientific_colors = ['#1f77b4', '#ff7f0e', '#2ca02c', '#d62728', '#9467bd', '#8c564b', '#e377c2', '#7f7f7f', '#bcbd22']
# Extract data for the chosen column from the concatenated DataFrames
data_columns_concatenated = {
    '25_15': df_25_15[column_to_compare],
     '25_30': df_25_30[column_to_compare],
     '50_15': df_50_15[column_to_compare],
     '50_30': df_50_30[column_to_compare],
     '75_15': df_75_15[column_to_compare],
     '75_30': df_75_30[column_to_compare],
    
    }

# Calculate mean and standard deviation
means = [data_column.mean() for data_column in data_columns_concatenated.values()]
std_devs = [data_column.std() for data_column in data_columns_concatenated.values()]
n_values = [len(data_column) for data_column in data_columns_concatenated.values()]

# Calculate 95% confidence interval
ci = [1.96 * std_dev / np.sqrt(n) for std_dev, n in zip(std_devs, n_values)]

# Prepare data for plotting
keys = list(data_columns_concatenated.keys())
x_pos = np.arange(len(keys))

# Plot bar graph with mean and standard deviation
plt.figure(figsize=(10, 6))
bars = plt.bar(x_pos, means, yerr=ci, align='center', alpha=0.7, ecolor='black', capsize=10, width=0.5, color=scientific_colors, edgecolor='black')

# Customize legend
legend_elements = [Patch(facecolor=color, label=key) for key, color in zip(keys, scientific_colors)]
plt.legend(handles=legend_elements, loc='upper left', bbox_to_anchor=(1, 1), title='Keys', frameon=False)

# Remove x-axis labels
plt.xticks([])

# Add data labels on top of the bars
for i, mean in enumerate(means):
    plt.text(x_pos[i], mean + 0.02 * max(means), f'{mean:.3f}', ha='center', va='bottom', fontsize=9)

plt.xlabel('Keys', fontsize=12)
plt.ylabel('Time (s)', fontsize=12)
plt.title(f'HMAC Comparison time in Fully-secure Protocol at 95% CI', fontsize=14)

# Remove the top and right spines for aesthetics
plt.gca().spines['top'].set_visible(False)
plt.gca().spines['right'].set_visible(False)

plt.show()

# %%
print(means)
print(ci)
# Out:
# [0.0002093107244488978, 0.00020591307200000002, 0.00020945549899999998, 0.000208220967, 0.00021399012838515548, 0.00023411869199999998]
# [2.301790065783092e-06, 1.98345245825602e-06, 2.013716501333035e-06, 2.343619313212173e-06, 1.8910709824104726e-06, 3.781265302244271e-06]

# %%
# Choose a column to compare

# Extract data for the chosen column from the concatenated DataFrames
data_columns_concatenated = {
    '25_15_sign': df_25_15['Signing Time'].apply(lambda x: eval(x)[0]),
    '25_15_verify': df_25_15['Signature Verification Time'].apply(lambda x: eval(x)[0]),
     '25_30_sign': df_25_30['Signing Time'].apply(lambda x: eval(x)[0]),
    '25_30_verify': df_25_30['Signature Verification Time'].apply(lambda x: eval(x)[0]),
     '50_15_sign': df_50_15['Signing Time'].apply(lambda x: eval(x)[0]),
    '50_15_verify': df_50_15['Signature Verification Time'].apply(lambda x: eval(x)[0]),
     '50_30_sign': df_50_30['Signing Time'].apply(lambda x: eval(x)[0]),
    '50_30_verify': df_50_30['Signature Verification Time'].apply(lambda x: eval(x)[0]),
    '75_15_sign': df_75_15['Signing Time'].apply(lambda x: eval(x)[0]),
    '75_15_verify': df_75_15['Signature Verification Time'].apply(lambda x: eval(x)[0]),
     '75_30_sign': df_75_30['Signing Time'].apply(lambda x: eval(x)[0]),
    '75_30_verify': df_75_30['Signature Verification Time'].apply(lambda x: eval(x)[0]),
    
     }


# Calculate mean and standard deviation
means = [data_column.mean() for data_column in data_columns_concatenated.values()]
std_devs = [data_column.std() for data_column in data_columns_concatenated.values()]

n_values = [len(data_column) for data_column in data_columns_concatenated.values()]

# Calculate 95% confidence interval
ci = [1.96 * std_dev / np.sqrt(n) for std_dev, n in zip(std_devs, n_values)]

# Prepare data for plotting
keys = list(data_columns_concatenated.keys())
x_pos = np.arange(len(keys))

# Plot bar graph with mean and standard deviation
plt.figure(figsize=(10, 6))
bars = plt.bar(x_pos, means, yerr=ci, align='center', alpha=0.7, ecolor='black', capsize=10, width=0.5, color=scientific_colors, edgecolor='black')

# Customize legend
legend_elements = [Patch(facecolor=color, label=key) for key, color in zip(keys, scientific_colors)]
plt.legend(handles=legend_elements, loc='upper left', bbox_to_anchor=(1, 1), title='Keys', frameon=False)

# Remove x-axis labels
plt.xticks([])

# Add data labels on top of the bars
for i, mean in enumerate(means):
    plt.text(x_pos[i], mean + 0.02 * max(means), f'{mean:.4f}', ha='center', va='bottom', fontsize=9)

plt.xlabel('Keys', fontsize=12)
plt.ylabel('Time (s)', fontsize=12)
plt.title(f'Signing and Verification Time for Fully-secure at 95% CI', fontsize=14)

# Remove the top and right spines for aesthetics
plt.gca().spines['top'].set_visible(False)
plt.gca().spines['right'].set_visible(False)

plt.show()

# %%
print(means)
print(ci)
# Out:
# [0.005415184942180504, 0.001354575634958271, 0.006439664840698242, 0.001281404972076416, 0.006060711622238159, 0.0013243000507354736, 0.006109509706497192, 0.0013110690116882324, 0.006096341545388117, 0.0013464869802430975, 0.006090725183486938, 0.0014090447425842286]
# [0.00031581522126066343, 1.458984097397086e-05, 0.0003621617631469964, 6.218096347874909e-06, 0.00034426939343693236, 8.390080605920294e-06, 0.0003417963473881111, 6.836643286560937e-06, 0.00033360987985184493, 7.569044375645356e-06, 0.00033705670718518066, 1.4125988098524008e-05]

# %%
# Choose a column to compare

# Extract data for the chosen column from the concatenated DataFrames
data_columns_concatenated = {
    '25_15_sign': df_25_15['AES-GCM Encryption Time'].apply(lambda x: eval(x)[0]),
    '25_30_sign': df_25_30['AES-GCM Encryption Time'].apply(lambda x: eval(x)[0]),
    '50_15_sign': df_50_15['AES-GCM Encryption Time'].apply(lambda x: eval(x)[0]),
     '50_30_sign': df_50_30['AES-GCM Encryption Time'].apply(lambda x: eval(x)[0]),
    '75_15_sign': df_75_15['AES-GCM Encryption Time'].apply(lambda x: eval(x)[0]),
     '75_30_sign': df_75_30['AES-GCM Encryption Time'].apply(lambda x: eval(x)[0]),
    
     }


# Calculate mean and standard deviation
means = [data_column.mean() for data_column in data_columns_concatenated.values()]
std_devs = [data_column.std() for data_column in data_columns_concatenated.values()]

n_values = [len(data_column) for data_column in data_columns_concatenated.values()]

# Calculate 95% confidence interval
ci = [1.96 * std_dev / np.sqrt(n) for std_dev, n in zip(std_devs, n_values)]

# Prepare data for plotting
keys = list(data_columns_concatenated.keys())
x_pos = np.arange(len(keys))

# Plot bar graph with mean and standard deviation
plt.figure(figsize=(10, 6))
bars = plt.bar(x_pos, means, yerr=ci, align='center', alpha=0.7, ecolor='black', capsize=10, width=0.5, color=scientific_colors, edgecolor='black')

# Customize legend
legend_elements = [Patch(facecolor=color, label=key) for key, color in zip(keys, scientific_colors)]
plt.legend(handles=legend_elements, loc='upper left', bbox_to_anchor=(1, 1), title='Keys', frameon=False)

# Remove x-axis labels
plt.xticks([])

# Add data labels on top of the bars
for i, mean in enumerate(means):
    plt.text(x_pos[i], mean + 0.02 * max(means), f'{mean:.4f}', ha='center', va='bottom', fontsize=9)

plt.xlabel('Keys', fontsize=12)
plt.ylabel('Time (s)', fontsize=12)
plt.title(f'AES-GCM Encryption Time for Fully-secure at 95% CI', fontsize=14)

# Remove the top and right spines for aesthetics
plt.gca().spines['top'].set_visible(False)
plt.gca().spines['right'].set_visible(False)

plt.show()

# %%
print(means)
print(ci)
# Out:
# [0.0005616671097780278, 0.0006758770942687988, 0.0006344671249389649, 0.0006829409599304199, 0.0005388169016020229, 0.0007307648658752442]
# [2.9290171717760046e-05, 3.890340987341698e-05, 2.9463592781056343e-05, 2.9216575361843346e-05, 2.4898590240741243e-05, 4.9957326574023144e-05]
